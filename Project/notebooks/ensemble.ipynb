# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import sklearn.metrics

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/bert-preds/submission_5_epochs (2).csv
# /kaggle/input/trans-gpt2/__results__.html
# /kaggle/input/trans-gpt2/submission_1_bce_epochs.csv
# /kaggle/input/trans-gpt2/__notebook__.ipynb
# /kaggle/input/trans-gpt2/__output__.json
# /kaggle/input/trans-gpt2/gpt2_bce_1_epochs.h5
# /kaggle/input/trans-gpt2/custom.css
# /kaggle/input/transformers/electra_1_bce_epochs.h5
# /kaggle/input/transformers/__results__.html
# /kaggle/input/transformers/submission_1_bce_epochs.csv
# /kaggle/input/transformers/__notebook__.ipynb
# /kaggle/input/transformers/__output__.json
# /kaggle/input/transformers/custom.css
# /kaggle/input/jigsaw-toxic-comment-classification-challenge/train.csv.zip
# /kaggle/input/jigsaw-toxic-comment-classification-challenge/sample_submission.csv.zip
# /kaggle/input/jigsaw-toxic-comment-classification-challenge/test_labels.csv.zip
# /kaggle/input/jigsaw-toxic-comment-classification-challenge/test.csv.zip

# %%
# !pip install transformers clean-text

# %%
submission_path_g = '/kaggle/input/trans-gpt2/submission_1_bce_epochs.csv'
submission_g = pd.read_csv(submission_path_g)
submission_g.head()

# %%
submission_path_e = '/kaggle/input/transformers/submission_1_bce_epochs.csv'
submission_e = pd.read_csv(submission_path_e)
submission_e.head()

# %%
submission_path_b = '/kaggle/input/bert-preds/submission_5_epochs (2).csv'
submission_b = pd.read_csv(submission_path_b)
submission_b.head()
# Out:
#                  id     toxic  severe_toxic   obscene    threat    insult  \
# 0  00001cee341fdb12  0.961089      0.250063  0.930815  0.063181  0.748455
# 1  0000247867823ef7  0.005151      0.000045  0.002282  0.000170  0.001001
# 2  00013b17ad220c46  0.004665      0.000034  0.001847  0.000144  0.000762
# 3  00017563c3f7919a  0.000843      0.000004  0.000278  0.000028  0.000115
# 4  00017695ad8997eb  0.005329      0.000026  0.001451  0.000156  0.000695
#
#    identity_hate
# 0       0.095988
# 1       0.000146
# 2       0.000185
# 3       0.000019
# 4       0.000156

# %%
target_columns = submission_g.columns[1:]
# print(target_columns)
ids = submission_e['id']
ensemble = submission_e[target_columns].to_numpy()*0.2 + submission_g[target_columns].to_numpy()*0.4 + submission_g[target_columns].to_numpy()*0.4
# print(pd.DataFrame(ensemble, columns=target_columns))
ensemble = pd.concat([ids, pd.DataFrame(ensemble, columns=target_columns)], axis=1)
ensemble.head()

# %%
submission_b.to_csv('submission_ensemble_b.csv', index=False)

submission_b.head()
# Out:
#                  id     toxic  severe_toxic   obscene    threat    insult  \
# 0  00001cee341fdb12  0.961089      0.250063  0.930815  0.063181  0.748455
# 1  0000247867823ef7  0.005151      0.000045  0.002282  0.000170  0.001001
# 2  00013b17ad220c46  0.004665      0.000034  0.001847  0.000144  0.000762
# 3  00017563c3f7919a  0.000843      0.000004  0.000278  0.000028  0.000115
# 4  00017695ad8997eb  0.005329      0.000026  0.001451  0.000156  0.000695
#
#    identity_hate
# 0       0.095988
# 1       0.000146
# 2       0.000185
# 3       0.000019
# 4       0.000156
